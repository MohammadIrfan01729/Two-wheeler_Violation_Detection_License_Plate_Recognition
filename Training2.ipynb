# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import shutil

base_path = "/content/drive/MyDrive/MP/final_dataset/twowheeler_train_val"

train_images = os.path.join(base_path, "train/images")
train_labels = os.path.join(base_path, "train/labels")

val_images = os.path.join(base_path, "val/images")
val_labels = os.path.join(base_path, "val/labels")

# %%
# Get all image files
images = [f for f in os.listdir(train_images) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Shuffle randomly
random.shuffle(images)

# Select 20%
split_count = int(0.2 * len(images))
move_images = images[:split_count]

print(f"Total images: {len(images)}")
print(f"Moving {split_count} images to validation...")

# %%
for img in move_images:
    # Image paths
    src_img = os.path.join(train_images, img)
    dst_img = os.path.join(val_images, img)

    # Label name (same name, .txt)
    label_name = os.path.splitext(img)[0] + ".txt"
    src_label = os.path.join(train_labels, label_name)
    dst_label = os.path.join(val_labels, label_name)

    # Move image
    shutil.move(src_img, dst_img)

    # Move label if exists
    if os.path.exists(src_label):
        shutil.move(src_label, dst_label)
    else:
        print(f"Warning: Label not found for {img}")

# %%
print("Dataset split completed successfully!")

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.6 MB/s eta 0:00:00
# ...

# %%
import os

folder_path = '/content/drive/MyDrive/MP/final_dataset/twowheeler_train_val'
yaml_drive_path = os.path.join(folder_path, 'dataset.yaml')

os.makedirs(folder_path, exist_ok=True)

yaml_content = """
path: /content/drive/MyDrive/MP/final_dataset/twowheeler_train_val

train: train/images
val: val/images

nc: 1
names: ['two_wheeler']
"""

with open(yaml_drive_path, 'w') as f:
    f.write(yaml_content)

print(f"✅ YAML created at: {yaml_drive_path}")

# %%
from ultralytics import YOLO

# Load pretrained model
model = YOLO('yolo11n.pt')  # you can also try yolo11s.pt for better accuracy

# Train
model.train(
    data='/content/drive/MyDrive/MP/final_dataset/twowheeler_train_val/dataset.yaml',
    project='/content/drive/MyDrive/MP/final_dataset/twowheeler_train_val/runs',
    name='twowheeler_model',
    epochs=60,
    imgsz=640,
    batch=16,
    device=0,
    val=True,        # force validation
    plots=True       # force plot generation
)

# %%
import os
import random
import shutil

base_path = "/content/drive/MyDrive/MP/final_dataset/rider_train_val"

train_images = os.path.join(base_path, "train/images")
train_labels = os.path.join(base_path, "train/labels")

val_images = os.path.join(base_path, "val/images")
val_labels = os.path.join(base_path, "val/labels")

# %%
# Get all images
images = [f for f in os.listdir(train_images) if f.endswith(('.jpg', '.png', '.jpeg'))]

random.shuffle(images)

split_count = int(0.2 * len(images))
move_images = images[:split_count]

print(f"Total images: {len(images)}")
print(f"Moving {split_count} images...")

# %%
for img in move_images:
    src_img = os.path.join(train_images, img)
    dst_img = os.path.join(val_images, img)

    label_name = os.path.splitext(img)[0] + ".txt"
    src_label = os.path.join(train_labels, label_name)
    dst_label = os.path.join(val_labels, label_name)

    shutil.move(src_img, dst_img)

    if os.path.exists(src_label):
        shutil.move(src_label, dst_label)
    else:
        print(f"⚠️ Missing label for {img}")

# %%
folder_path = "/content/drive/MyDrive/MP/final_dataset/rider_train_val"
yaml_path = os.path.join(folder_path, "dataset.yaml")

yaml_content = """
path: /content/drive/MyDrive/MP/final_dataset/rider_train_val

train: train/images
val: val/images

nc: 1
names: ['rider']
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("✅ YAML created!")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')  # or yolo11s.pt for better accuracy

model.train(
    data='/content/drive/MyDrive/MP/final_dataset/rider_train_val/dataset.yaml',
    project='/content/drive/MyDrive/MP/final_dataset/rider_train_val/runs',
    name='rider_model',
    epochs=60,
    imgsz=640,
    batch=16,
    device=0,
    val=True,
    plots=True
)

# %%
import os

val_img_path = "/content/drive/MyDrive/MP/final_dataset/rider_train_val/val/images"
val_lbl_path = "/content/drive/MyDrive/MP/final_dataset/rider_train_val/val/labels"

print("Val Images:", len(os.listdir(val_img_path)))
print("Val Labels:", len(os.listdir(val_lbl_path)))

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/MP/final_dataset/rider_train_val/runs/rider_model/weights/best.pt')

model.val(
    data='/content/drive/MyDrive/MP/final_dataset/rider_train_val/dataset.yaml',
    plots=True
)

# %%
model.predict(source=val_img_path, save=True)

# %%
import os
import random
import shutil

base_path = "/content/drive/MyDrive/MP/final_dataset/helmet_no_helmet_train_val"

train_images = os.path.join(base_path, "train/images")
train_labels = os.path.join(base_path, "train/labels")

val_images = os.path.join(base_path, "val/images")
val_labels = os.path.join(base_path, "val/labels")

# %%
images = [f for f in os.listdir(train_images) if f.endswith(('.jpg', '.png', '.jpeg'))]

random.shuffle(images)

split_count = int(0.2 * len(images))
move_images = images[:split_count]

print(f"Total images: {len(images)}")
print(f"Moving {split_count} images...")

# %%
for img in move_images:
    src_img = os.path.join(train_images, img)
    dst_img = os.path.join(val_images, img)

    label_name = os.path.splitext(img)[0] + ".txt"
    src_label = os.path.join(train_labels, label_name)
    dst_label = os.path.join(val_labels, label_name)

    shutil.move(src_img, dst_img)

    if os.path.exists(src_label):
        shutil.move(src_label, dst_label)
    else:
        print(f"⚠️ Missing label for {img}")

# %%
folder_path = "/content/drive/MyDrive/MP/final_dataset/helmet_no_helmet_train_val"
yaml_path = os.path.join(folder_path, "dataset.yaml")

yaml_content = """
path: /content/drive/MyDrive/MP/final_dataset/helmet_no_helmet_train_val

train: train/images
val: val/images

nc: 2
names: ['helmet', 'no_helmet']
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("✅ YAML created!")

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')  # or yolo11s.pt for better results

model.train(
    data='/content/drive/MyDrive/MP/final_dataset/helmet_no_helmet_train_val/dataset.yaml',
    project='/content/drive/MyDrive/MP/final_dataset/helmet_no_helmet_train_val/runs',
    name='helmet_model',
    epochs=60,
    imgsz=640,
    batch=16,
    device=0,
    val=True,
    plots=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
